# %% [markdown]
# # Southwest Airlines - Exploratory Data Analysis
#
# ## Load data and libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../dataset/raw_data.csv")
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (11109, 21)
#    year  month carrier            carrier_name airport  \
# 0  2023      8      WN  Southwest Airlines Co.     ABQ
# 1  2023      8      WN  Southwest Airlines Co.     ALB
# 2  2023      8      WN  Southwest Airlines Co.     AMA
# 3  2023      8      WN  Southwest Airlines Co.     ATL
# 4  2023      8      WN  Southwest Airlines Co.     AUS
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Albuquerque, NM: Albuquerque International Sun...       1003.0      237.0
# 1                   Albany, NY: Albany International        312.0      107.0
# 2  Amarillo, TX: Rick Husband Amarillo International        207.0       33.0
# 3  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       3143.0      717.0
# 4       Austin, TX: Austin - Bergstrom International       3169.0      623.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0       72.39        1.47  ...         0.00            137.04           12.0
# 1       45.40        1.00  ...         0.00             45.25            4.0
# 2       12.80        0.00  ...         0.00             16.42            1.0
# 3      183.49       26.09  ...         0.00            288.91           34.0
# 4      185.41       11.02  ...         2.52            312.24           32.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           0.0     9768.0         2718.0           53.0     1114.0
# 1           0.0     5040.0         2004.0           50.0      484.0
# 2           0.0      989.0          403.0            0.0       93.0
# 3          15.0    41231.0         9166.0         2453.0    14291.0
# 4          10.0    29059.0         8067.0          816.0     3928.0
#
#    security_delay  late_aircraft_delay
# 0             0.0               5883.0
# 1             0.0               2502.0
# 2             0.0                493.0
# 3             0.0              15321.0
# 4            97.0              16151.0
#
# [5 rows x 21 columns]

# %%
# Standardize column names and types
original_cols = df.columns.tolist()
df.columns = [c.strip().lower() for c in df.columns]

# Ensure numeric types
numeric_cols = [
    'arr_flights','arr_del15','carrier_ct','weather_ct','nas_ct','security_ct','late_aircraft_ct',
    'arr_cancelled','arr_diverted','arr_delay','carrier_delay','weather_delay','nas_delay','security_delay','late_aircraft_delay'
]
for col in numeric_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Create date field (year, month -> period and date)
if {'year','month'}.issubset(df.columns):
    df['year'] = df['year'].astype(int)
    df['month'] = df['month'].astype(int)
    df['year_month'] = pd.to_datetime(dict(year=df['year'], month=df['month'], day=1))
else:
    raise ValueError("Expected columns 'year' and 'month' in dataset")

print(df.dtypes.head(20))
df.tail(3)
# Out:
# year                  int32
# month                 int32
# carrier              object
# carrier_name         object
# airport              object
# airport_name         object
# arr_flights         float64
# arr_del15           float64
# carrier_ct          float64
# weather_ct          float64
# nas_ct              float64
# security_ct         float64
# late_aircraft_ct    float64
# arr_cancelled       float64
# arr_diverted        float64
# arr_delay           float64
# carrier_delay       float64
# weather_delay       float64
# nas_delay           float64
# security_delay      float64
# dtype: object
#        year  month carrier            carrier_name airport  \
# 11106  2013      8      WN  Southwest Airlines Co.     PHX
# 11107  2013      8      WN  Southwest Airlines Co.     PIT
# 11108  2013      8      WN  Southwest Airlines Co.     GRR
#
#                                          airport_name  arr_flights  arr_del15  \
# 11106   Phoenix, AZ: Phoenix Sky Harbor International       4986.0     1267.0
# 11107        Pittsburgh, PA: Pittsburgh International        535.0      164.0
# 11108  Grand Rapids, MI: Gerald R. Ford International        123.0       39.0
#
#        carrier_ct  weather_ct  ...  late_aircraft_ct  arr_cancelled  \
# 11106      367.33       16.66  ...            695.93           28.0
# 11107       49.05        3.81  ...             92.04            0.0
# 11108       17.81        0.00  ...             13.28            1.0
#
#        arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 11106          17.0    55837.0        15556.0          727.0     6081.0
# 11107           1.0     7853.0         1932.0          264.0      884.0
# 11108           0.0     1537.0          842.0            0.0      203.0
#
#        security_delay  late_aircraft_delay  year_month
# 11106            87.0              33386.0  2013-08-01
# 11107             0.0               4773.0  2013-08-01
# 11108             0.0                492.0  2013-08-01
#
# [3 rows x 22 columns]

# %%
# - delay_rate: proportion of delayed arrivals (>=15 min)
# - avg_delay_min_per_arrival: total delay time per arrival
# - cause_shares: proportions per delay cause

# Protection against division by zero
df['delay_rate'] = df['arr_del15'] / df['arr_flights']
df['avg_delay_min_per_arrival'] = df['arr_delay'] / df['arr_flights']

cause_delay_cols = ['carrier_delay','weather_delay','nas_delay','security_delay','late_aircraft_delay']
cause_ct_cols = ['carrier_ct','weather_ct','nas_ct','security_ct','late_aircraft_ct']

# Proportions of delay time per cause
cause_delay_sum = df[cause_delay_cols].sum(axis=1)
for col in cause_delay_cols:
    share_col = f"{col}_share"
    df[share_col] = np.where(cause_delay_sum > 0, df[col] / cause_delay_sum, np.nan)

# Proportion of delay incidents per cause (counts)
cause_ct_sum = df[cause_ct_cols].sum(axis=1)
for col in cause_ct_cols:
    share_col = f"{col}_share"
    df[share_col] = np.where(cause_ct_sum > 0, df[col] / cause_ct_sum, np.nan)

kpi_cols = ['delay_rate','avg_delay_min_per_arrival'] + [c+"_share" for c in (cause_delay_cols+cause_ct_cols)]
df[kpi_cols].describe().T
# Out:
#                              count       mean       std  min       25%  \
# delay_rate                 11109.0   0.205420  0.092726  0.0  0.143564
# avg_delay_min_per_arrival  11109.0  10.288931  5.559667  0.0  6.479042
# carrier_delay_share        11089.0   0.364873  0.121519  0.0  0.286482
# weather_delay_share        11089.0   0.027380  0.040905  0.0  0.000000
# nas_delay_share            11089.0   0.124668  0.090704  0.0  0.066493
# security_delay_share       11089.0   0.002427  0.010574  0.0  0.000000
# late_aircraft_delay_share  11089.0   0.480651  0.133633  0.0  0.413004
# carrier_ct_share           11089.0   0.378463  0.110874  0.0  0.305714
# weather_ct_share           11089.0   0.018406  0.028306  0.0  0.000000
# nas_ct_share               11089.0   0.155058  0.097881  0.0  0.088906
# security_ct_share          11089.0   0.002573  0.008592  0.0  0.000000
# late_aircraft_ct_share     11089.0   0.445500  0.119357  0.0  0.382159
#
#                                 50%        75%        max
# delay_rate                 0.201717   0.263754   0.628415
# avg_delay_min_per_arrival  9.536706  13.418284  43.165131
# carrier_delay_share        0.346862   0.420000   1.000000
# weather_delay_share        0.014295   0.036943   1.000000
# nas_delay_share            0.102896   0.155853   1.000000
# security_delay_share       0.000000   0.001471   0.464286
# late_aircraft_delay_share  0.495450   0.567115   1.000000
# carrier_ct_share           0.365806   0.433175   1.000000
# weather_ct_share           0.010432   0.024872   1.000000
# nas_ct_share               0.134687   0.199419   1.000000
# security_ct_share          0.000000   0.002344   0.334448
# late_aircraft_ct_share     0.455882   0.520873   1.000000

# %% [markdown]
# ## Time series plotting

# %%
# time series and totals
net = df.groupby('year_month', as_index=False).agg(
    flights=('arr_flights','sum'),
    delayed=('arr_del15','sum'),
    delay_min=('arr_delay','sum')
)
net['delay_rate'] = net['delayed'] / net['flights']
net['avg_delay_min_per_arrival'] = net['delay_min'] / net['flights']

fig, axes = plt.subplots(2,1, figsize=(12,8), sharex=True)
sns.lineplot(data=net, x='year_month', y='delay_rate', ax=axes[0])
axes[0].set_title('Delay Rate Over Time')
axes[0].set_ylabel('Delay Rate')

sns.lineplot(data=net, x='year_month', y='avg_delay_min_per_arrival', ax=axes[1], color='darkorange')
axes[1].set_title('Average Delay Minutes per Arrival')
axes[1].set_ylabel('Min/Arrival')
plt.tight_layout()

net.tail()
# Out:
#     year_month   flights  delayed  delay_min  delay_rate  \
# 116 2023-04-01  115946.0  29278.0  1489957.0    0.252514
# 117 2023-05-01  122521.0  25058.0  1169671.0    0.204520
# 118 2023-06-01  119251.0  35058.0  1850536.0    0.293985
# 119 2023-07-01  126469.0  39050.0  2208263.0    0.308771
# 120 2023-08-01  125664.0  28374.0  1341692.0    0.225793
#
#      avg_delay_min_per_arrival
# 116                  12.850439
# 117                   9.546698
# 118                  15.517991
# 119                  17.460903
# 120                  10.676821

# %% [markdown]
# ## Top airports with delay

# %%
last_date = df['year_month'].max()
first_date = df['year_month'].min()

if (last_date - first_date).days >= 365:
    cutoff = last_date - pd.DateOffset(years=1)
    df_rank = df[df['year_month'] > cutoff].copy()
else:
    df_rank = df.copy()

rank = df_rank.groupby('airport', as_index=False).agg(
    flights=('arr_flights','sum'),
    delayed=('arr_del15','sum'),
    delay_min=('arr_delay','sum')
)
rank['delay_rate'] = rank['delayed'] / rank['flights']
rank['avg_delay_min_per_arrival'] = rank['delay_min'] / rank['flights']

# Filter meaningful volume
rank = rank[rank['flights'] >= 200]

# Top 15 by delay_rate and by avg_delay
top_rate = rank.sort_values('delay_rate', ascending=False).head(15)
top_avg = rank.sort_values('avg_delay_min_per_arrival', ascending=False).head(15)

fig, axes = plt.subplots(1,2, figsize=(14,6))
sns.barplot(data=top_rate, y='airport', x='delay_rate', ax=axes[0], palette='Reds_r')
axes[0].set_title('Top Airports by Delay Rate')
sns.barplot(data=top_avg, y='airport', x='avg_delay_min_per_arrival', ax=axes[1], palette='Oranges_r')
axes[1].set_title('Top Airports by Minutes per Arrival')
plt.tight_layout()

rank.sort_values('delay_rate', ascending=False).head(10)
# Out:
# C:\Users\karoo\AppData\Local\Temp\ipykernel_14892\300828135.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_rate, y='airport', x='delay_rate', ax=axes[0], palette='Reds_r')
# C:\Users\karoo\AppData\Local\Temp\ipykernel_14892\300828135.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_avg, y='airport', x='avg_delay_min_per_arrival', ax=axes[1], palette='Oranges_r')
#    airport  flights  delayed  delay_min  delay_rate  avg_delay_min_per_arrival
# 94     SFO   8749.0   2751.0   139633.0    0.314436                  15.959881
# 30     FAT   1418.0    445.0    21129.0    0.313822                  14.900564
# 96     SJU   3651.0   1110.0    61910.0    0.304026                  16.956998
# 25     DSM   1659.0    502.0    26761.0    0.302592                  16.130802
# 10     BOS   5916.0   1741.0    93035.0    0.294287                  15.725997
# 82     PWM   1366.0    399.0    17729.0    0.292094                  12.978770
# 59     MEM   2949.0    853.0    44331.0    0.289251                  15.032553
# 86     ROC   1926.0    557.0    27960.0    0.289200                  14.517134
# 74     PBI   2095.0    605.0    32000.0    0.288783                  15.274463
# 26     DTW   3792.0   1073.0    51065.0    0.282964                  13.466508

# %% [markdown]
# ## Dig into causes for delays

# %%
# Cause analysis for top delayed airports
# Select top N from rank
TOP_N = 10
focus_airports = rank.sort_values('delay_rate', ascending=False).head(TOP_N)['airport'].tolist()

cause_cols = ['carrier_delay','weather_delay','nas_delay','security_delay','late_aircraft_delay']
subset = df[df['airport'].isin(focus_airports)].copy()

cause_by_airport = subset.groupby('airport', as_index=False)[cause_cols].sum()
# Maintain order from focus_airports
cause_by_airport = cause_by_airport.set_index('airport').loc[focus_airports].reset_index()

# True stacked horizontal bar plot
ax = cause_by_airport.set_index('airport')[cause_cols].plot(
    kind='barh', stacked=True, figsize=(12,6), colormap='tab20'
)
ax.set_title('Delay Minutes per Cause for Top Airports')
ax.set_xlabel('Minutes')
ax.set_ylabel('Airport')
plt.legend(title='Cause', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()

cause_by_airport.head()
# Out:
#   airport  carrier_delay  weather_delay  nas_delay  security_delay  \
# 0     SFO       472753.0        96068.0   748685.0          1764.0
# 1     FAT        18194.0          497.0     3795.0            82.0
# 2     SJU       149971.0        21858.0    47392.0          2394.0
# 3     DSM        39125.0         2192.0     9371.0            16.0
# 4     BOS       368395.0        67299.0   271173.0          1454.0
#
#    late_aircraft_delay
# 0             941433.0
# 1              26522.0
# 2             175193.0
# 3              65509.0
# 4             443898.0

# %% [markdown]
# We can remove weather delay as airlines can not do anything with it

# %% [markdown]
# ## Proportion heatmap

# %%
# Heatmap: proportion of delay time per cause (normalized per airport)
shares = subset.groupby('airport', as_index=False)[cause_cols].sum()
row_sum = shares[cause_cols].sum(axis=1)
share_matrix = shares.copy()
for c in cause_cols:
    share_matrix[c] = np.where(row_sum>0, shares[c]/row_sum, np.nan)

# Present heatmap
heat = share_matrix.set_index('airport')[cause_cols]
plt.figure(figsize=(10,6))
sns.heatmap(heat, annot=True, fmt='.0%', cmap='YlOrRd')
plt.title('Proportion of Delay per Cause (Top Airports)')
plt.ylabel('Airport')
plt.xlabel('Cause')
plt.tight_layout()

heat.head()
# Out:
#          carrier_delay  weather_delay  nas_delay  security_delay  \
# airport
# BOS           0.319727       0.058408   0.235348        0.001262
# DSM           0.336666       0.018862   0.080636        0.000138
# DTW           0.368169       0.032646   0.103773        0.001649
# FAT           0.370625       0.010124   0.077307        0.001670
# MEM           0.366306       0.044390   0.092760        0.001632
#
#          late_aircraft_delay
# airport
# BOS                 0.385255
# DSM                 0.563698
# DTW                 0.493764
# FAT                 0.540273
# MEM                 0.494913

# %% [markdown]
# Again, we can confirm that weather and security delay can be dropped from the dataset.

# %%
# Prioritization logic: combine volume and risk
prior = rank.copy()

# Normalize indicators 0-1
for col in ['flights','delay_rate','avg_delay_min_per_arrival']:
    m, M = prior[col].min(), prior[col].max()
    prior[f'{col}_norm'] = np.where(M>m, (prior[col]-m)/(M-m), 0.0)

# Weighted priority score (adjustable)
# Weighs both volume and severity
prior['priority_score'] = 0.4*prior['flights_norm'] + 0.3*prior['delay_rate_norm'] + 0.3*prior['avg_delay_min_per_arrival_norm']

# Add dominant cause
cause_cols = ['carrier_delay','weather_delay','nas_delay','security_delay','late_aircraft_delay']
recent_subset = df_rank.groupby('airport', as_index=False)[cause_cols].sum()
recent_subset['dominant_cause'] = recent_subset[cause_cols].idxmax(axis=1)

prior = prior.merge(recent_subset[['airport','dominant_cause']], on='airport', how='left')

priorities = prior.sort_values('priority_score', ascending=False).head(15)
priorities[['airport','flights','delay_rate','avg_delay_min_per_arrival','dominant_cause','priority_score']].reset_index(drop=True)
# Out:
#    airport  flights  delay_rate  avg_delay_min_per_arrival  \
# 0      LAS  81836.0    0.256342                  13.258138
# 1      DEN  92612.0    0.223686                  12.329417
# 2      SFO   8749.0    0.314436                  15.959881
# 3      SJU   3651.0    0.304026                  16.956998
# 4      DSM   1659.0    0.302592                  16.130802
# 5      MCO  39502.0    0.244443                  14.182649
# 6      BOS   5916.0    0.294287                  15.725997
# 7      FAT   1418.0    0.313822                  14.900564
# 8      MDW  76876.0    0.203418                  10.940541
# 9      DAL  69849.0    0.204670                  11.115735
# 10     PBI   2095.0    0.288783                  15.274463
# 11     MEM   2949.0    0.289251                  15.032553
# 12     MIA   6529.0    0.272017                  14.921427
# 13     ROC   1926.0    0.289200                  14.517134
# 14     PHX  61436.0    0.215395                  10.736083
#
#          dominant_cause  priority_score
# 0   late_aircraft_delay        0.725998
# 1   late_aircraft_delay        0.681529
# 2   late_aircraft_delay        0.603773
# 3   late_aircraft_delay        0.593337
# 4   late_aircraft_delay        0.555851
# 5   late_aircraft_delay        0.548499
# 6   late_aircraft_delay        0.545810
# 7   late_aircraft_delay        0.537261
# 8   late_aircraft_delay        0.530740
# 9   late_aircraft_delay        0.508089
# 10        carrier_delay        0.504480
# 11  late_aircraft_delay        0.501440
# 12  late_aircraft_delay        0.480782
# 13  late_aircraft_delay        0.480614
# 14  late_aircraft_delay        0.479868

# %%
# Action recommendations based on dominant causes
reco_map = {
    'carrier_delay': 'Increase buffer in rotation plan, strengthen maintenance and ground staffing.',
    'weather_delay': 'Seasonal and weather planning: flexible slots, extra reserve aircraft/crew.',
    'nas_delay': 'Coordinate with ATC; adjust departure times; spread traffic during peak.',
    'security_delay': 'Optimize security processes; better coordination with TSA.',
    'late_aircraft_delay': 'Better block times, turnaround efficiency, reserve aircraft to break cascade effects.'
}

priorities['recommendation'] = priorities['dominant_cause'].map(reco_map)

priorities[['airport','dominant_cause','recommendation','priority_score']].head(10)
# Out:
#    airport       dominant_cause  \
# 48     LAS  late_aircraft_delay
# 24     DEN  late_aircraft_delay
# 94     SFO  late_aircraft_delay
# 96     SJU  late_aircraft_delay
# 25     DSM  late_aircraft_delay
# 57     MCO  late_aircraft_delay
# 10     BOS  late_aircraft_delay
# 30     FAT  late_aircraft_delay
# 58     MDW  late_aircraft_delay
# 22     DAL  late_aircraft_delay
#
#                                        recommendation  priority_score
# 48  Better block times, turnaround efficiency, res...        0.725998
# 24  Better block times, turnaround efficiency, res...        0.681529
# 94  Better block times, turnaround efficiency, res...        0.603773
# 96  Better block times, turnaround efficiency, res...        0.593337
# 25  Better block times, turnaround efficiency, res...        0.555851
# 57  Better block times, turnaround efficiency, res...        0.548499
# 10  Better block times, turnaround efficiency, res...        0.545810
# 30  Better block times, turnaround efficiency, res...        0.537261
# 58  Better block times, turnaround efficiency, res...        0.530740
# 22  Better block times, turnaround efficiency, res...        0.508089

# %%
# Export key tables to CSV
out_dir = Path('dataset')
out_dir.mkdir(parents=True, exist_ok=True)

rank.to_csv(out_dir / 'southwest_airports_rank.csv', index=False)
priorities.to_csv(out_dir / 'southwest_priorities.csv', index=False)

print('Saved:', out_dir / 'southwest_airports_rank.csv')
print('Saved:', out_dir / 'southwest_priorities.csv')
# Out:
# Saved: dataset\southwest_airports_rank.csv
# Saved: dataset\southwest_priorities.csv

# %% [markdown]
# ## Interpretation and Actions
#
# - **High-risk airports**: Based on `priority_score` and delay profile.
# - **Dominant causes**: See heatmap and `dominant_cause` per airport.
# - **Operational actions** (examples):
#   - Carrier/operational: Optimize rotations, increase buffer in block times, staffing and maintenance.
#   - Late aircraft: Reserve aircraft/crew to break cascade effects; improve turnaround.
#   - NAS: Adjust departures to ATC capacity; spread peak traffic.
#   - Weather: Seasonal adaptation; alternative slots; pre-tactical planning.
#   - Security: Streamline ground processes and coordination.
#
# ## Scope and Limitations
# - Data structure: Aggregated monthly figures per airport – route level missing.
# - Cause attributes: May overlap and be influenced by reporting practices.
# - Not included: Cost/benefit calculations, crew/aircraft availability, gate capacity.
# - Predictive modeling is outside scope of this notebook.
#
# ## Future Work
# - Connect to route data (origin-destination) and time of day for more precise actions.
# - Seasonal and weather features for better explanation/prediction.
# - Test actions with A/B or before/after comparisons.
# - Operational KPI dashboards for continuous monitoring.
